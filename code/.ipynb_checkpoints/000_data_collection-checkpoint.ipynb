# %%
import gzip
from bs4 import BeautifulSoup
import urllib
import re

import urllib2
import json
import csv
import time
from __future__ import division


###Set proxy info
proxy = urllib2.ProxyHandler({'http': 'http://sjdalton:Babycat1@proxy.indra.es:8080/'})
opener = urllib2.build_opener(proxy)
urllib2.install_opener(opener)


use_proxy = 'YES'
path = "/media/jupiter/hadoopuser/amazon/data/"
pull_ids = 'NO'
get_meta_info = 'YES'
scrape_meta_info ='YES'
if use_proxy == 'NO':
    proxy=''

import requests
opener = urllib2.build_opener(proxy)
opener.addheaders = [('User-agent', 'Mozilla/5.0')]

#change to category name of items scraping
#if change from drill, need to change text filter in line 198
category_name="drill"


###These should be URLS of product search pages selected by the user (contain 20 products/page)

#exclude brush,case, reconditioned, refurbished & title must have drill

urlList=["http://www.amazon.com/s/ref=sr_nr_p_36_2?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253530011&keywords=drill&ie=UTF8&qid=1432901118&rnid=1243644011",
      "http://www.amazon.com/s/ref=sr_pg_2?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253530011&page=2&keywords=drill&ie=UTF8&qid=1432901605",
      "http://www.amazon.com/s/ref=sr_pg_3?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253530011&page=3&keywords=drill&ie=UTF8&qid=1432901711",
      "http://www.amazon.com/s/ref=sr_pg_4?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253530011&page=4&keywords=drill&ie=UTF8&qid=1432901836",
      "http://www.amazon.com/s/ref=sr_pg_5?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253530011&page=5&keywords=drill&ie=UTF8&qid=1432901865"
      "http://www.amazon.com/s/ref=sr_pg_7?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253530011&page=7&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902412",
      "http://www.amazon.com/s/ref=sr_nr_p_36_1?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253529011&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902528&rnid=1243644011",
      "http://www.amazon.com/s/ref=sr_pg_2?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253529011&page=2&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902543",
      "http://www.amazon.com/s/ref=sr_pg_3?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253529011&page=3&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902595",
      "http://www.amazon.com/s/ref=sr_pg_4?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253529011&page=4&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902708",
      "http://www.amazon.com/s/ref=sr_nr_p_36_3?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253531011&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902528&rnid=1243644011",
      "http://www.amazon.com/s/ref=sr_pg_2?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253531011&page=2&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902869",
      "http://www.amazon.com/s/ref=sr_pg_3?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253531011&page=3&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432902933",
      "http://www.amazon.com/s/ref=sr_pg_4?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253531011&page=4&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432903010",
      "http://www.amazon.com/s/ref=sr_pg_5?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253531011&page=5&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432903143",
      "http://www.amazon.com/s/ref=sr_pg_6?fst=as%3Aoff&rh=n%3A228013%2Cn%3A328182011%2Cn%3A551236%2Cn%3A552794%2Cn%3A9022404011%2Ck%3Adrill%2Cp_n_feature_four_browse-bin%3A9060577011%2Cp_36%3A1253531011&page=6&sort=relevancerank&keywords=drill&ie=UTF8&qid=1432903114"]


def get_soup(url):
    opener = urllib2.build_opener(proxy)
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    r1=opener.open(url)
    #r1=requests.get(url)
    soup = BeautifulSoup(r1.read(),'html.parser')
    ids=[ re.findall("[0-9A-Z]{10}",item)[0] for  item in re.findall("data-asin=\"[0-9A-Z]{10}\"",str(soup))]
    return ids



file_name= path+category_name+"_ids.txt"

if pull_ids == 'YES':
    listOfIds=[get_soup(item) for item in urlList]
    listOfIds2=list(set(str(listOfIds).replace("[","").replace("]","").replace(",","").replace("'","").split()))
    with open(file_name,"w") as f:
        f.write(str(listOfIds2).replace("[","").replace("]",""))
else:
    print('Not rerunning to pull ids')



####get product info


#Function to Get product meta data
def get_meta(asin):
    meta={}
    amazonUrl = 'http://www.amzn.com/'
    url= amazonUrl + asin
    opener = urllib2.build_opener(proxy)
    opener.addheaders = [('User-agent', 'Mozilla/5.0')]
    r = opener.open(url)
    s = BeautifulSoup(r.read())
    print(str(s)[0:20])
    print(asin)
    meta["asin"] = asin
    meta["productTitle"] = s.find_all(id="productTitle")[0].get_text()
    meta["category"]=str(re.findall("\S+\s", s.find_all(id="wayfinding-breadcrumbs_feature_div")[0].get_text().encode('ascii','ignore'))).replace("'",'').replace(",",'').replace("[",'').replace("]",'').split("\\n")    
    meta["scrapeDate"] = int(time.time())
    try:
        meta["ladderSalesRank"]=re.sub("#",'',s.find_all("span", class_="zg_hrsr_rank")[0].get_text()).replace(',','')
        meta["categoryLadder"]=[item.get_text() for item in s.find_all("span", class_="zg_hrsr_ladder")[0].find_all("a")]
    except:
        meta["ladderSalesRank"]="Rescrape"
        meta["categoryLadder"]="Rescrape"
    try:
        meta["mainCategorySalesRank"]=re.findall("[^A-Za-z\s]+",s.find_all(id="SalesRank")[0].find_all("td",class_="value")[0].get_text().replace('\n',''))[0].replace('#','').replace(',','')
        meta["mainCategory"]=re.findall("[A-Za-z\s]+",s.find_all(id="SalesRank")[0].find_all("td",class_="value")[0].get_text().replace('\n',''))[0].replace(' in','')
    except:
        meta["mainCategorySalesRank"]="Rescrape"
        meta["mainCategory"]="Rescrape"


    try:
        meta["price"] = str(s.find_all(id="priceblock_ourprice")[0].get_text())
    except:
        meta["price"] = "unavailable"
    try:
        meta["shipping"] = str(s.find_all(id="ourprice_shippingmessage")[0].get_text().replace('\n',''))
    except:
        meta["shipping"] = "unavailable"
    try:
        meta["savings"] = re.findall("\$[0-9]*.[0-9]*", str(s.find_all(id="regularprice_savings")[0].get_text()))[0]
    except:
         meta["savings"] = 0
    try:        
        meta["description"] = s.find_all(id="feature-bullets")[0].get_text().encode('ascii','ignore').replace('\n','').replace('See more product details','')
    except:
        meta["description"] = unknown
    try:
        meta["dateFirstAvailable"] = [item.find(class_="value").get_text() for item in s.find_all("tr")                                   if str(item).find("date-first-available") > -1][0]
    except:
        meta["dateFirstAvailable"] = 'unavailable'
    try:
        meta["productsPurchasedAfter"]=[item.replace("reviews/","") for  item in set(re.findall("reviews/[0-9A-Z]{10}",               str(s.find_all(id="view_to_purchase-sims-feature")[0].find_all(class_="a-link-normal"))))]
    except:
        meta["productsAlsoViewed"]='Unknown'
    try:
        meta["otherSellers"] = s.find_all(id="mbc")[0].get_text().encode('ascii','ignore').replace('\n','')
    except:
        meta["otherSellers"] = 'unavailable'
    try:
        meta["numOfReviews"]=int(re.findall("[^A-Za-z\s]+",s.find_all(id="acrCustomerReviewText")[0].get_text())[0].replace(",",''))
    except:
        meta["numOfReviews"]= 0
    return meta


######Use product Ids collected from search pages to scrape prices

if scrape_meta_info=='YES':
    if pull_ids == 'NO':
        list_of_ids=open(path+category_name+"_ids.txt","r")
        asin_list=list(set(list_of_ids.read().replace("'",'').replace(",","").split()))
        list_of_ids.close()
    else:
        print('Using new ids pulled and stored in memory')

    url_error=[]

    file_name=path+"meta_" + category_name + time.strftime("%Y%m%d") + ".txt"
    with open(file_name,"w") as f:
        meta_info=[]
        for idx,item in enumerate(asin_list):
            print(str(idx) +' ' + item)
            try:
                info=get_meta(item)
                meta_info.append(info)
                f.write(json.dumps(info) + ',')
                time.sleep(randint(4,7))
                if (idx % 30) == 0 & idx!=0:
                    time.sleep(100)
            except:
                url_error.append(item)

######GET META INFO (PRICE AND SALES RANK INFO)

if scrape_meta_info=='NO':
    if get_meta_info=='YES':
        text=open(path+"meta_" + category_name+"s" + time.strftime("%Y%m%d") + ".txt", "r").read()
        import ast
        meta_info=ast.literal_eval(text)

if scrape_meta_info=='YES' or get_meta_info=='YES':        
    asins_to_keep=[]
    meta_info1=[]
    counter=0
    for idx,item in enumerate(meta_info):
        try:
            if int(item["numOfReviews"]) >= 20:
            #if item["numOfReviews"] == "Unknown":
                if item["productTitle"].lower().find(category_name) > -1:
                    counter += 1
                    asins_to_keep.append(item["asin"])
                    meta_info1.append(item)
        except:
            None


    meta_json = json.dumps(obj = meta_info1,indent = 4)
    fd = open(path + "meta_" + category_name + "_final_" + time.strftime("%Y%m%d") + ".json", "w")
    fd.write(meta_json)
    fd.close()


outfile=open(path + "meta_" + category_name + "_final.txt","w")
ids=[row["asin"].encode('ascii','ignore') for row in meta_info1]
print(ids)
outfile.write("\n".join(ids))
# Out:
# Not rerunning to pull ids
# 0 B000PI48AK
# <!DOCTYPE html>
# <!--
# B000PI48AK
# 1 B00B5OOCQ8
# <!DOCTYPE html>
# <!--
# B00B5OOCQ8
# 2 B008YFV55C
# <!DOCTYPE html>
# <!--
# B008YFV55C
# 3 B00TV27MZE
# <!DOCTYPE html>
# <!--
# B00TV27MZE
# 4 B000VUR3KO
# <!DOCTYPE html>
# <!--
# B000VUR3KO
# 5 B00AW5FY2M
# <!DOCTYPE html>
# <!--
# B00AW5FY2M
# 6 B00OJ72LHU
# <!DOCTYPE html>
# <!--
# B00OJ72LHU
# 7 B008E76BZ4
# <!DOCTYPE html>
# <!--
# B008E76BZ4
# 8 B00BD5G3UC
# <!DOCTYPE html>
# <!--
# B00BD5G3UC
# 9 B00FGIPZWO
# <!DOCTYPE html>
# <!--
# B00FGIPZWO
# 10 B00B74YORI
# <!DOCTYPE html>
# <!--
# B00B74YORI
# 11 B000X1PZVK
# <!DOCTYPE html>
# <!--
# B000X1PZVK
# 12 B00QSR0RE8
# <!DOCTYPE html>
# <!--
# B00QSR0RE8
# 13 B007EE3638
# <!DOCTYPE html>
# <!--
# B007EE3638
# 14 B00BYFNCBO
# <!DOCTYPE html>
# <!--
# B00BYFNCBO
# 15 B00I8N70L8
# <!DOCTYPE html>
# <!--
# B00I8N70L8
# 16 B00LAFBRIS
# <!DOCTYPE html>
# <!--
# B00LAFBRIS
# 17 B00NW4KCHM
# <!DOCTYPE html>
# <!--
# B00NW4KCHM
# 18 B0098RHSZQ
# <!DOCTYPE html>
# <!--
# B0098RHSZQ
# 19 B00EB23PL4
# <!DOCTYPE html>
# <!--
# B00EB23PL4
# 20 B00ET3T352
# <!DOCTYPE html>
# <!--
# B00ET3T352
# 21 B00GPPX420
# <!DOCTYPE html>
# <!--
# B00GPPX420
# 22 B0009HAHDO
# <!DOCTYPE html>
# <!--
# B0009HAHDO
# 23 B0040ZLPGY
# <!DOCTYPE html>
# <!--
# B0040ZLPGY
# 24 B00GPPW6ME
# <!DOCTYPE html>
# <!--
# B00GPPW6ME
# 25 B004ELBE42
# <!DOCTYPE html>
# <!--
# B004ELBE42
# 26 B004GHA512
# <!DOCTYPE html>
# <!--
# B004GHA512
# 27 B00NEN03X4
# <!DOCTYPE html>
# <!--
# B00NEN03X4
# 28 B003A9HGIM
# <!DOCTYPE html>
# <!--
# B003A9HGIM
# 29 B00C7CK6E4
# <!DOCTYPE html>
# <!--
# B00C7CK6E4
# 30 B002EEP4ZG
# <!DOCTYPE html>
# <!--
# B002EEP4ZG
# 31 B00436U5GG
# <!DOCTYPE html>
# <!--
# B00436U5GG
# 32 B0043XX89A
# <!DOCTYPE html>
# <!--
# B0043XX89A
# 33 B004V7P4KO
# <!DOCTYPE html>
# <!--
# B004V7P4KO
# 34 B002VWK5SC
# <!DOCTYPE html>
# <!--
# B002VWK5SC
# 35 B00L9EIZ2Q
# <!DOCTYPE html>
# <!--
# B00L9EIZ2Q
# 36 B00973Z5W4
# <!DOCTYPE html>
# <!--
# B00973Z5W4
# 37 B008ZHAB5O
# <!DOCTYPE html>
# <!--
# B008ZHAB5O
# 38 B00N3W7122
# <!DOCTYPE html>
# <!--
# B00N3W7122
# 39 B007283O56
# <!DOCTYPE html>
# <!--
# B007283O56
# 40 B00COVRV8C
# <!DOCTYPE html>
# <!--
# B00COVRV8C
# 41 B007EO8GL0
# <!DOCTYPE html>
# <!--
# B007EO8GL0
# 42 B00960ERUE
# <!DOCTYPE html>
# <!--
# B00960ERUE
# 43 B00NOVOTJ0
# <!DOCTYPE html>
# <!--
# B00NOVOTJ0
# 44 B00E0NMWMW
# <!DOCTYPE html>
# <!--
# B00E0NMWMW
# 45 B0000CCXUU
# <!DOCTYPE html>
# <!--
# B0000CCXUU
# 46 B00HUCUF4W
# <!DOCTYPE html>
# <!--
# B00HUCUF4W
# 47 B003XWXVW6
# <!DOCTYPE html>
# <!--
# B003XWXVW6
# 48 B00AN8PWX4
# <!DOCTYPE html>
# <!--
# B00AN8PWX4
# 49 B004VN3MYI
# <!DOCTYPE html>
# <!--
# B004VN3MYI
# 50 B0052MIHMO
# <!DOCTYPE html>
# <!--
# B0052MIHMO
# 51 B00HUCUF9M
# <!DOCTYPE html>
# <!--
# B00HUCUF9M
# 52 B005MNC6PW
# <!DOCTYPE html>
# <!--
# B005MNC6PW
# 53 B00A41YTHA
# <!DOCTYPE html>
# <!--
# B00A41YTHA
# 54 B00E5ZF7OK
# <!DOCTYPE html>
# <!--
# B00E5ZF7OK
# 55 B005F9SZTE
# <!DOCTYPE html>
# <!--
# B005F9SZTE
# 56 B00HFILRUC
# <!DOCTYPE html>
# <!--
# B00HFILRUC
# 57 B00F1HR3JI
# <!DOCTYPE html>
# <!--
# B00F1HR3JI
# 58 B00006IIO7
# <!DOCTYPE html>
# <!--
# B00006IIO7
# 59 B00270KOOS
# <!DOCTYPE html>
# <!--
# B00270KOOS
# 60 B007Q60H40
# <!DOCTYPE html>
# <!--
# B007Q60H40
# 61 B000X1TYO4
# <!DOCTYPE html>
# <!--
# B000X1TYO4
# 62 B00PQVSQDQ
# <!DOCTYPE html>
# <!--
# B00PQVSQDQ
# 63 B005OY97QU
# <!DOCTYPE html>
# <!--
# B005OY97QU
# 64 B002YBFXYG
# <!DOCTYPE html>
# <!--
# B002YBFXYG
# 65 B00NW4KCLS
# <!DOCTYPE html>
# <!--
# B00NW4KCLS
# 66 B007XU2TDG
# <!DOCTYPE html>
# <!--
# B007XU2TDG
# 67 B00AY1DKHA
# <!DOCTYPE html>
# <!--
# B00AY1DKHA
# 68 B002UYVF44
# <!DOCTYPE html>
# <!--
# B002UYVF44
# 69 B00W31EAYG
# <!DOCTYPE html>
# <!--
# B00W31EAYG
# 70 B009PDWBYG
# <!DOCTYPE html>
# <!--
# B009PDWBYG
# 71 B004WJKVYK
# <!DOCTYPE html>
# <!--
# B004WJKVYK
# 72 B001EYURZE
# <!DOCTYPE html>
# <!--
# B001EYURZE
# 73 B00FFZQ0WC
# <!DOCTYPE html>
# <!--
# B00FFZQ0WC
# 74 B00FR6V5YM
# <!DOCTYPE html>
# <!--
# B00FR6V5YM
# 75 B00GPPV8ZK
# <!DOCTYPE html>
# <!--
# B00GPPV8ZK
# 76 B00HQUS02C
# <!DOCTYPE html>
# <!--
# B00HQUS02C
# 77 B00BD5G5CI
# <!DOCTYPE html>
# <!--
# B00BD5G5CI
# 78 B00AY8XJ9M
# <!DOCTYPE html>
# <!--
# B00AY8XJ9M
# 79 B005B7D5EU
# <!DOCTYPE html>
# <!--
# B005B7D5EU
# 80 B00E1VE6VI
# <!DOCTYPE html>
# <!--
# B00E1VE6VI
# 81 B00MF2YANE
# <!DOCTYPE html>
# <!--
# B00MF2YANE
# 82 B004443WW6
# <!DOCTYPE html>
# <!--
# B004443WW6
# 83 B0047ZMHOQ
# <!DOCTYPE html>
# <!--
# B0047ZMHOQ
# 84 B0052MIIAK
# <!DOCTYPE html>
# <!--
# B0052MIIAK
# 85 B00ELQYCUI
# <!DOCTYPE html>
# <!--
# B00ELQYCUI
# 86 B00CR93GIK
# <!DOCTYPE html>
# <!--
# B00CR93GIK
# 87 B004U4BAI8
# <!DOCTYPE html>
# <!--
# B004U4BAI8
# 88 B000RERWXC
# <!DOCTYPE html>
# <!--
# B000RERWXC
# 89 B00S09OGWQ
# <!DOCTYPE html>
# <!--
# B00S09OGWQ
# 90 B00UZVPARM
# <!DOCTYPE html>
# <!--
# B00UZVPARM
# 91 B002XFWYUY
# <!DOCTYPE html>
# <!--
# B002XFWYUY
# 92 B00569JTXO
# <!DOCTYPE html>
# <!--
# B00569JTXO
# 93 B004KG4SS0
# <!DOCTYPE html>
# <!--
# B004KG4SS0
# 94 B005LTNLDI
# <!DOCTYPE html>
# <!--
# B005LTNLDI
# 95 B00F0XR55A
# <!DOCTYPE html>
# <!--
# B00F0XR55A
# 96 B0058YA67A
# <!DOCTYPE html>
# <!--
# B0058YA67A
# 97 B00G2EEN10
# <!DOCTYPE html>
# <!--
# B00G2EEN10
# 98 B004D29IA4
# <!DOCTYPE html>
# <!--
# B004D29IA4
# 99 B0076R6TVO
# <!DOCTYPE html>
# <!--
# B0076R6TVO
# 100 B00C625KPA
# <!DOCTYPE html>
# <!--
# B00C625KPA
# 101 B000140B4A
# <!DOCTYPE html>
# <!--
# B000140B4A
# 102 B00IIUERJE
# <!DOCTYPE html>
# <!--
# B00IIUERJE
# 103 B002WJUFRU
# <!DOCTYPE html>
# <!--
# B002WJUFRU
# 104 B00P5OQ3FW
# <!DOCTYPE html>
# <!--
# B00P5OQ3FW
# 105 B003BI6WA0
# <!DOCTYPE html>
# <!--
# B003BI6WA0
# 106 B0045JK3F4
# <!DOCTYPE html>
# <!--
# B0045JK3F4
# 107 B00EPE7PLY
# <!DOCTYPE html>
# <!--
# B00EPE7PLY
# 108 B005CX8822
# <!DOCTYPE html>
# <!--
# B005CX8822
# 109 B00B5OOF1A
# <!DOCTYPE html>
# <!--
# B00B5OOF1A
# 110 B00008WFT3
# <!DOCTYPE html>
# <!--
# B00008WFT3
# 111 B008F0S8HO
# <!DOCTYPE html>
# <!--
# B008F0S8HO
# 112 B00198S2IE
# <!DOCTYPE html>
# <!--
# B00198S2IE
# 113 B00QE8BCZ4
# <!DOCTYPE html>
# <!--
# B00QE8BCZ4
# 114 B001U6EHAC
# <!DOCTYPE html>
# <!--
# B001U6EHAC
# 115 B005OSYGH6
# <!DOCTYPE html>
# <!--
# B005OSYGH6
# 116 B007ML7IEG
# <!DOCTYPE html>
# <!--
# B007ML7IEG
# 117 B00N8I29X2
# <!DOCTYPE html>
# <!--
# B00N8I29X2
# 118 B004Q05KVE
# <!DOCTYPE html>
# <!--
# B004Q05KVE
# 119 B00J5IJ7XE
# <!DOCTYPE html>
# <!--
# B00J5IJ7XE
# 120 B00U1TG0AO
# <!DOCTYPE html>
# <!--
# B00U1TG0AO
# 121 B00H081EEQ
# <!DOCTYPE html>
# <!--
# B00H081EEQ
# 122 B0050RBKYS
# <!DOCTYPE html>
# <!--
# B0050RBKYS
# 123 B00FRMSMWY
# <!DOCTYPE html>
# <!--
# B00FRMSMWY
# 124 B00B5OOCW2
# <!DOCTYPE html>
# <!--
# B00B5OOCW2
# 125 B001QMRSDI
# <!DOCTYPE html>
# <!--
# B001QMRSDI
# 126 B001N2NTEI
# <!DOCTYPE html>
# <!--
# B001N2NTEI
# 127 B00A99318A
# <!DOCTYPE html>
# <!--
# B00A99318A
# 128 B00E1FFAKA
# <!DOCTYPE html>
# <!--
# B00E1FFAKA
# 129 B002RT7K4Q
# <!DOCTYPE html>
# <!--
# B002RT7K4Q
# 130 B00E2ZTRE4
# <!DOCTYPE html>
# <!--
# B00E2ZTRE4
# 131 B008J1MUOG
# <!DOCTYPE html>
# <!--
# B008J1MUOG
# 132 B001F7BIKS
# <!DOCTYPE html>
# <!--
# B001F7BIKS
# 133 B00IQYN0U4
# <!DOCTYPE html>
# <!--
# B00IQYN0U4
# 134 B003HIWR26
# <!DOCTYPE html>
# <!--
# B003HIWR26
# 135 B0015Z3Q8M
# <!DOCTYPE html>
# <!--
# B0015Z3Q8M
# 136 B004AQFCVW
# <!DOCTYPE html>
# <!--
# B004AQFCVW
# 137 B004Y74AU6
# <!DOCTYPE html>
# <!--
# B004Y74AU6
# 138 B002RT7K3W
# <!DOCTYPE html>
# <!--
# B002RT7K3W
# 139 B001NPDR5G
# <!DOCTYPE html>
# <!--
# B001NPDR5G
# 140 B00CSDII3S
# <!DOCTYPE html>
# <!--
# B00CSDII3S
# 141 B004LLKU18
# <!DOCTYPE html>
# <!--
# B004LLKU18
# 142 B001GZEVS0
# <!DOCTYPE html>
# <!--
# B001GZEVS0
# 143 B009MQTCFM
# <!DOCTYPE html>
# <!--
# B009MQTCFM
# 144 B0021ZVDIA
# <!DOCTYPE html>
# <!--
# B0021ZVDIA
# 145 B009K1H346
# <!DOCTYPE html>
# <!--
# B009K1H346
# 146 B002VWK5R8
# <!DOCTYPE html>
# <!--
# B002VWK5R8
# 147 B00K58OFKS
# <!DOCTYPE html>
# <!--
# B00K58OFKS
# 148 B00A1N9CPA
# <!DOCTYPE html>
# <!--
# B00A1N9CPA
# 149 B004MTECCW
# <!DOCTYPE html>
# <!--
# B004MTECCW
# 150 B00BD9XO1O
# <!DOCTYPE html>
# <!--
# B00BD9XO1O
# 151 B0037KM8TG
# <!DOCTYPE html>
# <!--
# B0037KM8TG
# 152 B00NUEFQXO
# <!DOCTYPE html>
# <!--
# B00NUEFQXO
# 153 B00J6N48KK
# <!DOCTYPE html>
# <!--
# B00J6N48KK
# 154 B008BSN9BK
# <!DOCTYPE html>
# <!--
# B008BSN9BK
# 155 B004MMSGV2
# <!DOCTYPE html>
# <!--
# B004MMSGV2
# 156 B006FVP73I
# <!DOCTYPE html>
# <!--
# B006FVP73I
# 157 B00NW4K9SE
# <!DOCTYPE html>
# <!--
# B00NW4K9SE
# 158 B002RLR0EY
# <!DOCTYPE html>
# <!--
# B002RLR0EY
# 159 B0040724EO
# <!DOCTYPE html>
# <!--
# B0040724EO
# 160 B0043XX88G
# <!DOCTYPE html>
# <!--
# B0043XX88G
# 161 B008YSHD0K
# <!DOCTYPE html>
# <!--
# B008YSHD0K
# 162 B00SGBQFZY
# <!DOCTYPE html>
# <!--
# B00SGBQFZY
# 163 B00I3PODXE
# <!DOCTYPE html>
# <!--
# B00I3PODXE
# 164 B003YKP0M6
# <!DOCTYPE html>
# <!--
# B003YKP0M6
# 165 B00949QSUO
# <!DOCTYPE html>
# <!--
# B00949QSUO
# 166 B00I36BQ56
# <!DOCTYPE html>
# <!--
# B00I36BQ56
# 167 B007C6KOJW
# <!DOCTYPE html>
# <!--
# B007C6KOJW
# 168 B00BLFLYW6
# <!DOCTYPE html>
# <!--
# B00BLFLYW6
# 169 B00009KDGY
# <!DOCTYPE html>
# <!--
# B00009KDGY
# 170 B004HEY0BU
# <!DOCTYPE html>
# <!--
# B004HEY0BU
# 171 B004EYI18G
# <!DOCTYPE html>
# <!--
# B004EYI18G
# 172 B00O100398
# <!DOCTYPE html>
# <!--
# B00O100398
# 173 B00KHCP88A
# <!DOCTYPE html>
# <!--
# B00KHCP88A
# 174 B005UD8MKW
# <!DOCTYPE html>
# <!--
# B005UD8MKW
# 175 B004MSM9KU
# <!DOCTYPE html>
# <!--
# B004MSM9KU
# 176 B00540B3NE
# <!DOCTYPE html>
# <!--
# B00540B3NE
# 177 B00LBOOKPK
# <!DOCTYPE html>
# <!--
# B00LBOOKPK
# 178 B003BYRFKK
# <!DOCTYPE html>
# <!--
# B003BYRFKK
# 179 B002SQK996
# <!DOCTYPE html>
# <!--
# B002SQK996
# 180 B000NV9LGU
# <!DOCTYPE html>
# <!--
# B000NV9LGU
# 181 B008PN5K9A
# <!DOCTYPE html>
# <!--
# B008PN5K9A
# 182 B002W1U4LA
# <!DOCTYPE html>
# <!--
# B002W1U4LA
# 183 B004NC23U6
# <!DOCTYPE html>
# <!--
# B004NC23U6
# 184 B008RIHXZW
# <!DOCTYPE html>
# <!--
# B008RIHXZW
# 185 B00AVDWSEC
# <!DOCTYPE html>
# <!--
# B00AVDWSEC
# 186 B00M9D67PS
# <!DOCTYPE html>
# <!--
# B00M9D67PS
# 187 B00O1WODJM
# <!DOCTYPE html>
# <!--
# B00O1WODJM
# 188 B00HUCUGFA
# <!DOCTYPE html>
# <!--
# B00HUCUGFA
# 189 B00IMKQB9O
# <!DOCTYPE html>
# <!--
# B00IMKQB9O
# 190 B0051GK2JM
# <!DOCTYPE html>
# <!--
# B0051GK2JM
# 191 B002EEP4W4
# <!DOCTYPE html>
# <!--
# B002EEP4W4
# 192 B003BEE2MY
# <!DOCTYPE html>
# <!--
# B003BEE2MY
# 193 B004PWEJD8
# <!DOCTYPE html>
# <!--
# B004PWEJD8
# 194 B00JV23M9O
# <!DOCTYPE html>
# <!--
# B00JV23M9O
# 195 B00AM1UZ34
# <!DOCTYPE html>
# <!--
# B00AM1UZ34
# 196 B009VK6G8U
# <!DOCTYPE html>
# <!--
# B009VK6G8U
# 197 B002S5A76M
# <!DOCTYPE html>
# <!--
# B002S5A76M
# 198 B00F5ZLK4A
# <!DOCTYPE html>
# <!--
# B00F5ZLK4A
# 199 B00J82AJFC
# <!DOCTYPE html>
# <!--
# B00J82AJFC
# 200 B005EB8J1W
# <!DOCTYPE html>
# <!--
# B005EB8J1W
# 201 B002W210HQ
# <!DOCTYPE html>
# <!--
# B002W210HQ
# 202 B001EYU8RG
# <!DOCTYPE html>
# <!--
# B001EYU8RG
# 203 B00DR07XM8
# <!DOCTYPE html>
# <!--
# B00DR07XM8
# 204 B00CKY3WE0
# <!DOCTYPE html>
# <!--
# B00CKY3WE0
# 205 B009K1H5CG
# <!DOCTYPE html>
# <!--
# B009K1H5CG
# 206 B005AZ39LM
# <!DOCTYPE html>
# <!--
# B005AZ39LM
# 207 B00J6F7A44
# <!DOCTYPE html>
# <!--
# B00J6F7A44
# 208 B00GPPUUIQ
# <!DOCTYPE html>
# <!--
# B00GPPUUIQ
# 209 B002RUENBS
# <!DOCTYPE html>
# <!--
# B002RUENBS
# 210 B00S065VI2
# <!DOCTYPE html>
# <!--
# B00S065VI2
# 211 B00MPEDLBY
# <!DOCTYPE html>
# <!--
# B00MPEDLBY
# 212 B00CGCY5NS
# <!DOCTYPE html>
# <!--
# B00CGCY5NS
# 213 B00TXG6V28
# <!DOCTYPE html>
# <!--
# B00TXG6V28
# 214 B0073YDIPU
# <!DOCTYPE html>
# <!--
# B0073YDIPU
# 215 B00HUCUF7E
# <!DOCTYPE html>
# <!--
# B00HUCUF7E
# 216 B00XIYUGM2
# <!DOCTYPE html>
# <!--
# B00XIYUGM2
# 217 B00VMH8KT8
# <!DOCTYPE html>
# <!--
# B00VMH8KT8
# 218 B006V6YAPI
# <!DOCTYPE html>
# <!--
# B006V6YAPI
# 219 B002X0A40G
# <!DOCTYPE html>
# <!--
# B002X0A40G
# 220 B007Q6ZQ5A
# <!DOCTYPE html>
# <!--
# B007Q6ZQ5A
# 221 B0026T3YF6
# <!DOCTYPE html>
# <!--
# B0026T3YF6
# 222 B001IO57P0
# <!DOCTYPE html>
# <!--
# B001IO57P0
# 223 B00AESM7KO
# <!DOCTYPE html>
# <!--
# B00AESM7KO
# 224 B002N2XJ8I
# <!DOCTYPE html>
# <!--
# B002N2XJ8I
# 225 B008726LWO
# <!DOCTYPE html>
# <!--
# B008726LWO
# 226 B00UXWILCY
# <!DOCTYPE html>
# <!--
# B00UXWILCY
# 227 B00H0KA9NQ
# <!DOCTYPE html>
# <!--
# B00H0KA9NQ
# 228 B000IBL1VS
# <!DOCTYPE html>
# <!--
# B000IBL1VS
# 229 B002Z0WB96
# <!DOCTYPE html>
# <!--
# B002Z0WB96
# 230 B00MMNFD6Y
# <!DOCTYPE html>
# <!--
# B00MMNFD6Y
# 231 B004443WVW
# <!DOCTYPE html>
# <!--
# B004443WVW
# 232 B009F0PZZG
# <!DOCTYPE html>
# <!--
# B009F0PZZG
# 233 B001EYURZY
# <!DOCTYPE html>
# <!--
# B001EYURZY
# 234 B0052TZFYU
# <!DOCTYPE html>
# <!--
# B0052TZFYU
# 235 B001UHOURG
# <!DOCTYPE html>
# <!--
# B001UHOURG
# 236 B003BEE12U
# <!DOCTYPE html>
# <!--
# B003BEE12U
# 237 B007NVSQEQ
# <!DOCTYPE html>
# <!--
# B007NVSQEQ
# 238 B004FDRDHG
# <!DOCTYPE html>
# <!--
# B004FDRDHG
# 239 B00NJKDL9U
# <!DOCTYPE html>
# <!--
# B00NJKDL9U
# 240 B00X52SRNW
# <!DOCTYPE html>
# <!--
# B00X52SRNW
# 241 B00JNZLZZM
# <!DOCTYPE html>
# <!--
# B00JNZLZZM
# 242 B002TROYKO
# <!DOCTYPE html>
# <!--
# B002TROYKO
# 243 B001N2NTD4
# <!DOCTYPE html>
# <!--
# B001N2NTD4
# 244 B0090CTI98
# <!DOCTYPE html>
# <!--
# B0090CTI98
# 245 B00ANQYETO
# <!DOCTYPE html>
# <!--
# B00ANQYETO
# 246 B009K1H3YG
# <!DOCTYPE html>
# <!--
# B009K1H3YG
# 247 B00JNA15GQ
# <!DOCTYPE html>
# <!--
# B00JNA15GQ
# 248 B007WGET4S
# <!DOCTYPE html>
# <!--
# B007WGET4S
# 249 B002VWK5QE
# <!DOCTYPE html>
# <!--
# B002VWK5QE
# 250 B005JRJCVM
# <!DOCTYPE html>
# <!--
# B005JRJCVM
# 251 B00VSB68ZQ
# <!DOCTYPE html>
# <!--
# B00VSB68ZQ
# 252 B009K1H35K
# <!DOCTYPE html>
# <!--
# B009K1H35K
# 253 B002VWK5QO
# <!DOCTYPE html>
# <!--
# B002VWK5QO
# 254 B001EYUS0I
# <!DOCTYPE html>
# <!--
# B001EYUS0I
# 255 B00AEU0SVW
# <!DOCTYPE html>
# <!--
# B00AEU0SVW
# 256 B002Q1PUSS
# <!DOCTYPE html>
# <!--
# B002Q1PUSS
# 257 B002VWK5Q4
# <!DOCTYPE html>
# <!--
# B002VWK5Q4
# 258 B005G2S0A4
# <!DOCTYPE html>
# <!--
# B005G2S0A4
# 259 B00BYFNEL2
# <!DOCTYPE html>
# <!--
# B00BYFNEL2
# 260 B00P43C53I
# <!DOCTYPE html>
# <!--
# B00P43C53I
# 261 B00QDEBWTU
# <!DOCTYPE html>
# <!--
# B00QDEBWTU
# 262 B0080L0IB2
# <!DOCTYPE html>
# <!--
# B0080L0IB2
# 263 B0009Q4MBI
# <!DOCTYPE html>
# <!--
# B0009Q4MBI
# 264 B002TFHOVC
# <!DOCTYPE html>
# <!--
# B002TFHOVC
# 265 B00FL1BXMW
# <!DOCTYPE html>
# <!--
# B00FL1BXMW
# 266 B00198MCHG
# <!DOCTYPE html>
# <!--
# B00198MCHG
# 267 B003LST02W
# <!DOCTYPE html>
# <!--
# B003LST02W
# 268 B00HFXSAE8
# <!DOCTYPE html>
# <!--
# B00HFXSAE8
# 269 B00GG0I2TE
# <!DOCTYPE html>
# <!--
# B00GG0I2TE
# 270 B00LO3GRCW
# <!DOCTYPE html>
# <!--
# B00LO3GRCW
# 271 B0040111AS
# <!DOCTYPE html>
# <!--
# B0040111AS
# 272 B00GLEWR96
# <!DOCTYPE html>
# <!--
# B00GLEWR96
# 273 B00BCVNDBE
# <!DOCTYPE html>
# <!--
# B00BCVNDBE
# 274 B00M46N1IQ
# <!DOCTYPE html>
# <!--
# B00M46N1IQ
# 275 B00NYBLXAS
# <!DOCTYPE html>
# <!--
# B00NYBLXAS
# 276 B00U2TP572
# <!DOCTYPE html>
# <!--
# B00U2TP572
# 277 B004CR6D2G
# <!DOCTYPE html>
# <!--
# B004CR6D2G
# 278 B005QPQ77Y
# <!DOCTYPE html>
# <!--
# B005QPQ77Y
# 279 B00VIQAR3A
# <!DOCTYPE html>
# <!--
# B00VIQAR3A
# 280 B00L0H5I8Q
# <!DOCTYPE html>
# <!--
# B00L0H5I8Q
# 281 B0052TZDAG
# <!DOCTYPE html>
# <!--
# B0052TZDAG
# 282 B00AF5CPU8
# <!DOCTYPE html>
# <!--
# B00AF5CPU8
# 283 B0027DXDW0
# <!DOCTYPE html>
# <!--
# B0027DXDW0
# 284 B005JE3VZ8
# <!DOCTYPE html>
# <!--
# B005JE3VZ8
# 285 B0043XX87W
# <!DOCTYPE html>
# <!--
# B0043XX87W
# 286 B00ONA4LTO
# <!DOCTYPE html>
# <!--
# B00ONA4LTO
# 287 B0020ML6XQ
# <!DOCTYPE html>
# <!--
# B0020ML6XQ
# 288 B000X1TYPS
# <!DOCTYPE html>
# <!--
# B000X1TYPS
# 289 B00FGAXXDA
# <!DOCTYPE html>
# <!--
# B00FGAXXDA
# 290 B00H5AA39Q
# <!DOCTYPE html>
# <!--
# B00H5AA39Q
# 291 B0073G4W26
# <!DOCTYPE html>
# <!--
# B0073G4W26
# 292 B00S013OE0
# <!DOCTYPE html>
# <!--
# B00S013OE0
# 293 B00339U01O
# <!DOCTYPE html>
# <!--
# B00339U01O
# 294 B005NNF0YU
# <!DOCTYPE html>
# <!--
# B005NNF0YU
# 295 B00CSDIK9U
# <!DOCTYPE html>
# <!--
# B00CSDIK9U
# 296 B00C625KVE
# <!DOCTYPE html>
# <!--
# B00C625KVE
# 297 B00FR6V6A0
# <!DOCTYPE html>
# <!--
# B00FR6V6A0
# 298 B0054M1AVM
# <!DOCTYPE html>
# <!--
# B0054M1AVM
# 299 B00EPE7NQQ
# <!DOCTYPE html>
# <!--
# B00EPE7NQQ
# 300 B0057I2Y54
# <!DOCTYPE html>
# <!--
# B0057I2Y54
# 301 B0035DVW56
# <!DOCTYPE html>
# <!--
# B0035DVW56
# 302 B0020ML6JU
# <!DOCTYPE html>
# <!--
# B0020ML6JU
# 303 B00BD5G5A0
# <!DOCTYPE html>
# <!--
# B00BD5G5A0
# 304 B003EAQU6G
# <!DOCTYPE html>
# <!--
# B003EAQU6G
# 305 B0098RHXD8
# <!DOCTYPE html>
# <!--
# B0098RHXD8
# 306 B009608CAK
# <!DOCTYPE html>
# <!--
# B009608CAK
# 307 B00ET5VMTU
# <!DOCTYPE html>
# <!--
# B00ET5VMTU
# 308 B003P9WJKC
# <!DOCTYPE html>
# <!--
# B003P9WJKC
# 309 B008J1NNX8
# <!DOCTYPE html>
# <!--
# B008J1NNX8
# 310 B001EYURYU
# <!DOCTYPE html>
# <!--
# B001EYURYU
# 311 B007N7IK96
# <!DOCTYPE html>
# <!--
# B007N7IK96
# 312 B00PBGOGKI
# <!DOCTYPE html>
# <!--
# B00PBGOGKI
# 313 B003BEE2LU
# <!DOCTYPE html>
# <!--
# B003BEE2LU
# 314 B004VYTY8K
# <!DOCTYPE html>
# <!--
# B004VYTY8K
# 315 B00I55M84I
# <!DOCTYPE html>
# <!--
# B00I55M84I
# 316 B000GIIRLK
# <!DOCTYPE html>
# <!--
# B000GIIRLK
# 317 B00BYFND22
# <!DOCTYPE html>
# <!--
# B00BYFND22
# 318 B00EQPV5HC
# <!DOCTYPE html>
# <!--
# B00EQPV5HC
# 319 B00L5XEZ7U
# <!DOCTYPE html>
# <!--
# B00L5XEZ7U
# 320 B007IH6RUK
# <!DOCTYPE html>
# <!--
# B007IH6RUK
# 321 B009K1H59Y
# <!DOCTYPE html>
# <!--
# B009K1H59Y
# 322 B00FWGB3DU
# <!DOCTYPE html>
# <!--
# B00FWGB3DU
# 323 B00GUTR5EE
# <!DOCTYPE html>
# <!--
# B00GUTR5EE
# 324 B0038IZ1JG
# <!DOCTYPE html>
# <!--
# B0038IZ1JG
# 325 B001GIPG1S
# <!DOCTYPE html>
# <!--
# B001GIPG1S
# 326 B0031DFFZ8
# <!DOCTYPE html>
# <!--
# B0031DFFZ8
# 327 B00AOJFOAS
# <!DOCTYPE html>
# <!--
# B00AOJFOAS
# 328 B00949QT4O
# <!DOCTYPE html>
# <!--
# B00949QT4O
# 329 B00PSUQIHG
# <!DOCTYPE html>
# <!--
# B00PSUQIHG
# 330 B00NTM5218
# <!DOCTYPE html>
# <!--
# B00NTM5218
# 331 B000VZPOVO
# <!DOCTYPE html>
# <!--
# B000VZPOVO
# 332 B00CSDIIXS
# <!DOCTYPE html>
# <!--
# B00CSDIIXS
# 333 B00FPKCXDM
# <!DOCTYPE html>
# <!--
# B00FPKCXDM
# 334 B007XZWXYQ
# <!DOCTYPE html>
# <!--
# B007XZWXYQ
# 335 B0009H4YIS
# <!DOCTYPE html>
# <!--
# B0009H4YIS
# 336 B00C625KQ4
# <!DOCTYPE html>
# <!--
# B00C625KQ4
# 337 B00PP6MAT8
# <!DOCTYPE html>
# <!--
# B00PP6MAT8
# 338 B004D29IBI
# <!DOCTYPE html>
# <!--
# B004D29IBI
# 339 B00VIKYPMU
# <!DOCTYPE html>
# <!--
# B00VIKYPMU
# 340 B0079IRIG0
# <!DOCTYPE html>
# <!--
# B0079IRIG0
# 341 B00ILHEE60
# <!DOCTYPE html>
# <!--
# B00ILHEE60
# 342 B00GPPUYDC
# <!DOCTYPE html>
# <!--
# B00GPPUYDC
# 343 B009JBBF0A
# <!DOCTYPE html>
# <!--
# B009JBBF0A
# 344 B00AN6B2SK
# <!DOCTYPE html>
# <!--
# B00AN6B2SK
# 345 B003CYKNVW
# <!DOCTYPE html>
# <!--
# B003CYKNVW
# 346 B007ML7HQ0
# <!DOCTYPE html>
# <!--
# B007ML7HQ0
# 347 B007ML7E8Q
# <!DOCTYPE html>
# <!--
# B007ML7E8Q
# 348 B009JBBF0K
# <!DOCTYPE html>
# <!--
# B009JBBF0K
# 349 B0052MIH88
# <!DOCTYPE html>
# <!--
# B0052MIH88
# 350 B00HUCUIMG
# <!DOCTYPE html>
# <!--
# B00HUCUIMG
# 351 B00CWQK6WM
# <!DOCTYPE html>
# <!--
# B00CWQK6WM
# 352 B00QCGA9J8
# <!DOCTYPE html>
# <!--
# B00QCGA9J8
# 353 B00NOVNUUY
# <!DOCTYPE html>
# <!--
# B00NOVNUUY
# 354 B00A3FUCYQ
# <!DOCTYPE html>
# <!--
# B00A3FUCYQ
# 355 B004I6S04U
# <!DOCTYPE html>
# <!--
# B004I6S04U
# 356 B00F61UA8A
# <!DOCTYPE html>
# <!--
# B00F61UA8A
# 357 B00KYNW7S6
# <!DOCTYPE html>
# <!--
# B00KYNW7S6
# 358 B00HUCUHPE
# <!DOCTYPE html>
# <!--
# B00HUCUHPE
# 359 B009K1H3Z0
# <!DOCTYPE html>
# <!--
# B009K1H3Z0
# 360 B002Q1TRDC
# <!DOCTYPE html>
# <!--
# B002Q1TRDC
# 361 B001F0R8TU
# <!DOCTYPE html>
# <!--
# B001F0R8TU
# 362 B007WUHQE4
# <!DOCTYPE html>
# <!--
# B007WUHQE4
# 363 B000077CPQ
# <!DOCTYPE html>
# <!--
# B000077CPQ
# 364 B00BRUUGWY
# <!DOCTYPE html>
# <!--
# B00BRUUGWY
# 365 B0046REI6U
# <!DOCTYPE html>
# <!--
# B0046REI6U
# 366 B00HUCUFCY
# <!DOCTYPE html>
# <!--
# B00HUCUFCY
# 367 B00HUCUFCO
# <!DOCTYPE html>
# <!--
# B00HUCUFCO
# 368 B0038N2PCW
# <!DOCTYPE html>
# <!--
# B0038N2PCW
# 369 B0046REI60
# <!DOCTYPE html>
# <!--
# B0046REI60
# 370 B00H4O9PA6
# <!DOCTYPE html>
# <!--
# B00H4O9PA6
# 371 B004NC3Z9O
# <!DOCTYPE html>
# <!--
# B004NC3Z9O
# 372 B00IIW4JQI
# <!DOCTYPE html>
# <!--
# B00IIW4JQI
# 373 B005ZX3CKW
# <!DOCTYPE html>
# <!--
# B005ZX3CKW
# 374 B002VWK5PU
# <!DOCTYPE html>
# <!--
# B002VWK5PU
# 375 B0050PWWGA
# <!DOCTYPE html>
# <!--
# B0050PWWGA
# 376 B00PQY56EU
# <!DOCTYPE html>
# <!--
# B00PQY56EU
# 377 B008337PJ0
# <!DOCTYPE html>
# <!--
# B008337PJ0

# %%
# Out:
# ['B00OJ72LHU', 'B00BD5G3UC', 'B000X1PZVK', 'B0009HAHDO', 'B002EEP4ZG', 'B004V7P4KO', 'B007283O56', 'B007EO8GL0', 'B00NOVOTJ0', 'B00E0NMWMW', 'B00HUCUF4W', 'B0052MIHMO', 'B005MNC6PW', 'B000X1TYO4', 'B007XU2TDG', 'B002UYVF44', 'B004WJKVYK', 'B001EYURZE', 'B00FFZQ0WC', 'B005B7D5EU', 'B00E1VE6VI', 'B00ELQYCUI', 'B000RERWXC', 'B005LTNLDI', 'B00F0XR55A', 'B004D29IA4', 'B00C625KPA', 'B00IIUERJE', 'B002WJUFRU', 'B0045JK3F4', 'B00B5OOF1A', 'B00008WFT3', 'B00N8I29X2', 'B00J5IJ7XE', 'B00FRMSMWY', 'B00B5OOCW2', 'B001N2NTEI', 'B008J1MUOG', 'B002RT7K3W', 'B00CSDII3S', 'B00A1N9CPA', 'B00BD9XO1O', 'B0037KM8TG', 'B002RLR0EY', 'B0040724EO', 'B008YSHD0K', 'B00BLFLYW6', 'B00009KDGY', 'B004EYI18G', 'B00540B3NE', 'B002SQK996', 'B002W1U4LA', 'B00O1WODJM', 'B002EEP4W4', 'B003BEE2MY', 'B001EYU8RG', 'B006V6YAPI', 'B007Q6ZQ5A', 'B001IO57P0', 'B00AESM7KO', 'B002Z0WB96', 'B001EYURZY', 'B0052TZFYU', 'B001UHOURG', 'B004FDRDHG', 'B002TROYKO', 'B001N2NTD4', 'B0090CTI98', 'B00ANQYETO', 'B009K1H3YG', 'B007WGET4S', 'B001EYUS0I', 'B005G2S0A4', 'B0009Q4MBI', 'B002TFHOVC', 'B00HFXSAE8', 'B004CR6D2G', 'B0052TZDAG', 'B00AF5CPU8', 'B0027DXDW0', 'B0043XX87W', 'B000X1TYPS', 'B00FR6V6A0', 'B0057I2Y54', 'B009608CAK', 'B00ET5VMTU', 'B000GIIRLK', 'B00BYFND22', 'B0031DFFZ8', 'B000VZPOVO', 'B00CSDIIXS', 'B0009H4YIS', 'B00C625KQ4', 'B0079IRIG0', 'B00AN6B2SK', 'B003CYKNVW', 'B007ML7E8Q', 'B0052MIH88', 'B00A3FUCYQ', 'B009K1H3Z0', 'B000077CPQ', 'B0046REI60', 'B002VWK5PU', 'B008337PJ0']

# %%
import gzip
from bs4 import BeautifulSoup
import urllib
import re

import urllib2
import json
import csv
import time
from __future__ import division


###Set proxy info
proxy = urllib2.ProxyHandler({'http': 'http://sjdalton:Babycat1@proxy.indra.es:8080/'})
opener = urllib2.build_opener(proxy)
urllib2.install_opener(opener)


use_proxy = 'YES'
path = "/media/jupiter/hadoopuser/amazon/data/"
pull_ids = 'NO'
get_meta_info = 'YES'
scrape_meta_info ='YES'
if use_proxy == 'NO':
    proxy=''

import requests
opener = urllib2.build_opener(proxy)
opener.addheaders = [('User-agent', 'Mozilla/5.0')]

#change to category name of items scraping
#if change from drill, need to change text filter in line 198
category_name="drill"
fd = open(path + "meta_" + category_name + "_final_" + time.strftime("%Y%m%d") + ".json", "r")
text = fd.read()
pmeta = json.loads(text)
fd.close()
print(pmeta[1])

print(pmeta[20])
# Out:
# {u'category': [u'Tools  &  Home  Improvement', u' Power  &  Hand  Tools', u' Power  Tools', u' Drills', u' Drill  Drivers', u''], u'asin': u'B00BD5G3UC', u'numOfReviews': 52, u'description': u' Enter your model numberabove to make sure this fits. A 12V motor provides 1,300 RPM as well as 115 in-lbs. max torque 5-position pivoting head articulates from 90-degrees to 180-degrees, making it perfect for working in tight areas 3/8-Inch auto lock chuck for simple bit replacements and a variety of applications Variable-speed trigger for perfect speed regulation Motor brake for exact serial screw driving', u'ladderSalesRank': u'Rescrape', u'categoryLadder': u'Rescrape', u'scrapeDate': 1436891205, u'mainCategory': u'Rescrape', u'dateFirstAvailable': u'unavailable', u'savings': u'$110.00', u'shipping': u'& FREE Shipping. Details', u'mainCategorySalesRank': u'Rescrape', u'productTitle': u'Bosch PS11-102 12-Volt Lithium-Ion Max 3/8-Inch Right Angle Drill/Driver Kit with (1) High Capacity Battery and Charger', u'otherSellers': u'Other Sellers on AmazonAdd to Cart                    $129.00                +$6.98shipping            Sold by:                    CPO Outlets        Add to Cart                    $129.00                +$6.99shipping            Sold by:                    Acme Tools        Add to Cart                    $153.34                +Free Shipping            Sold by:                    Independence Fulfillment Services        12newfrom$129.00', u'productsAlsoViewed': u'Unknown', u'price': u'$129.00'}
# {u'category': [u'Tools  &  Home  Improvement', u' Power  &  Hand  Tools', u' Power  Tools', u' Drills', u' Drill  Drivers', u''], u'asin': u'B00E1VE6VI', u'numOfReviews': 48, u'description': u' Enter your model numberabove to make sure this fits. Delivers up to 275 in lbs of Torque. On-board battery fuel gauge displays remaining run time New ergonomic handle design for increased comfort Metal Ratcheting Chuck for maximum durability', u'ladderSalesRank': u'Rescrape', u'categoryLadder': u'Rescrape', u'scrapeDate': 1436891412, u'mainCategory': u'Rescrape', u'dateFirstAvailable': u'unavailable', u'savings': u'$98.00', u'shipping': u'& FREE Shipping', u'mainCategorySalesRank': u'Rescrape', u'productTitle': u'Milwaukee 2407-20 M12 3/8" Drill/Driver (Bare)', u'otherSellers': u'Other Sellers on AmazonAdd to Cart                    $70.97                +Free Shipping            Sold by:                    DISCOUNTTOOLMALL        8used&newfrom$47.30', u'productsAlsoViewed': u'Unknown', u'price': u'$57.22'}

# %%
# Out:
# u'B00OJ72LHU'
